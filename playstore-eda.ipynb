# %% [markdown]
# # Google playstore EDA (Exploratory Data Analysis)

# %%
# libraries to use

import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# READ dATA FROM CSV FILE
# df = dataFrame
df = pd.read_csv('Google-Playstore.csv')

# %%
# view first five records 

df.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
# 1            5000.0              7662  True    0.0  ...
# ...

# %%
# view last five records

df.tail()
# Out:
#                              App Name                                App Id  \
# 2312939                      大俠客—熱血歸來                         com.rxsj.ssjj
# 2312940                    ORU Online              com.threedream.oruonline
# 2312941                Data Structure  datastructure.appoworld.datastucture
# 2312942                   Devi Suktam                     ishan.devi.suktam
# 2312943  Biliyor Musun - Sonsuz Yarış             com.yyazilim.biliyormusun
#
#               Category  Rating  Rating Count  Installs  Minimum Installs  \
# 2312939   Role Playing     4.3       16775.0  100,000+          100000.0
# 2312940      Education     0.0           0.0      100+             100.0
# 2312941      Education     0.0           0.0      100+             100.0
# 2312942  Music & Audio     3.5           8.0    1,000+            1000.0
# 2312943         Trivia     5.0          12.0      100+             100.0
#
#          Maximum Installs  Free  Price  ...  \
# ...

# %%
# shape of the data
df.shape
# Out:
# (2312944, 24)

# %%
# view all columns in the data
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
# view composition
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2312944 entries, 0 to 2312943
# Data columns (total 24 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   App Name           object
#  1   App Id             object
#  2   Category           object
#  3   Rating             float64
#  4   Rating Count       float64
#  5   Installs           object
#  6   Minimum Installs   float64
#  7   Maximum Installs   int64
#  8   Free               bool
#  9   Price              float64
#  10  Currency           object
#  11  Size               object
#  12  Minimum Android    object
#  13  Developer Id       object
#  14  Developer Website  object
#  15  Developer Email    object
#  16  Released           object
#  17  Last Updated       object
#  18  Content Rating     object
#  19  Privacy Policy     object
#  20  Ad Supported       bool
#  21  In App Purchases   bool
#  22  Editors Choice     bool
#  23  Scraped Time       object
# ...

# %%
# view descriptive stats
df.describe()
# Out:
#              Rating  Rating Count  Minimum Installs  Maximum Installs  \
# count  2.290061e+06  2.290061e+06      2.312837e+06      2.312944e+06
# mean   2.203152e+00  2.864839e+03      1.834452e+05      3.202017e+05
# std    2.106223e+00  2.121626e+05      1.513144e+07      2.355495e+07
# min    0.000000e+00  0.000000e+00      0.000000e+00      0.000000e+00
# 25%    0.000000e+00  0.000000e+00      5.000000e+01      8.400000e+01
# 50%    2.900000e+00  6.000000e+00      5.000000e+02      6.950000e+02
# 75%    4.300000e+00  4.200000e+01      5.000000e+03      7.354000e+03
# max    5.000000e+00  1.385576e+08      1.000000e+10      1.205763e+10
#
#               Price
# count  2.312944e+06
# mean   1.034992e-01
# std    2.633127e+00
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    4.000000e+02

# %%
# 5 numerical columns
# lets see missiong values

df.isnull().sum()
# Out:
# App Name                  2
# App Id                    0
# Category                  0
# Rating                22883
# Rating Count          22883
# Installs                107
# Minimum Installs        107
# Maximum Installs          0
# Free                      0
# Price                     0
# Currency                135
# Size                    196
# Minimum Android        6530
# Developer Id             33
# Developer Website    760835
# Developer Email          31
# Released              71053
# Last Updated              0
# Content Rating            0
# Privacy Policy       420953
# Ad Supported              0
# In App Purchases          0
# Editors Choice            0
# Scraped Time              0
# dtype: int64

# %%
# sort the above data
sort_data = df.isnull().sum().sort_values(ascending=False)
sort_data
# Out:
# Developer Website    760835
# Privacy Policy       420953
# Released              71053
# Rating                22883
# Rating Count          22883
# Minimum Android        6530
# Size                    196
# Currency                135
# Installs                107
# Minimum Installs        107
# Developer Id             33
# Developer Email          31
# App Name                  2
# App Id                    0
# Price                     0
# Free                      0
# Maximum Installs          0
# Last Updated              0
# Content Rating            0
# Category                  0
# Ad Supported              0
# In App Purchases          0
# Editors Choice            0
# Scraped Time              0
# dtype: int64

# %%
# lets see percentage of missing values
missing_perc = sort_data/len(df) * 100
missing_perc
# Out:
# Developer Website    32.894657
# Privacy Policy       18.199879
# Released              3.071972
# Rating                0.989345
# Rating Count          0.989345
# Minimum Android       0.282324
# Size                  0.008474
# Currency              0.005837
# Installs              0.004626
# Minimum Installs      0.004626
# Developer Id          0.001427
# Developer Email       0.001340
# App Name              0.000086
# App Id                0.000000
# Price                 0.000000
# Free                  0.000000
# Maximum Installs      0.000000
# Last Updated          0.000000
# Content Rating        0.000000
# Category              0.000000
# Ad Supported          0.000000
# In App Purchases      0.000000
# Editors Choice        0.000000
# Scraped Time          0.000000
# dtype: float64

# %%
# plot of missing/null value 
import missingno as msno
msno.matrix(df)
# Out:
# <AxesSubplot: >

# %%
missing_perc = missing_perc[missing_perc != 0]
# plot of missing/null values percentage
import matplotlib
matplotlib.rcParams['figure.figsize']= (20,6)
missing_perc.plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df.dropna(subset=['App Name','Developer Email','Developer Id','Minimum Installs','Installs','Currency','Size'],inplace=True)

# %%
df.isnull().sum()
# Out:
# App Name                  0
# App Id                    0
# Category                  0
# Rating                22572
# Rating Count          22572
# Installs                  0
# Minimum Installs          0
# Maximum Installs          0
# Free                      0
# Price                     0
# Currency                  0
# Size                      0
# Minimum Android        6530
# Developer Id              0
# Developer Website    760716
# Developer Email           0
# Released              70748
# Last Updated              0
# Content Rating            0
# Privacy Policy       420845
# Ad Supported              0
# In App Purchases          0
# Editors Choice            0
# Scraped Time              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique().sort_values(ascending=False)
# Out:
# App Id               2312548
# App Name             2177593
# Privacy Policy        977576
# Developer Email       950261
# Developer Website     810271
# Developer Id          758283
# Maximum Installs      251541
# Scraped Time           67374
# Rating Count           38482
# Released                4158
# Last Updated            3917
# Size                    1657
# Price                   1063
# Minimum Android          154
# Category                  48
# Rating                    42
# Minimum Installs          22
# Installs                  22
# Currency                  15
# Content Rating             6
# Free                       2
# Ad Supported               2
# In App Purchases           2
# Editors Choice             2
# dtype: int64

# %%
# Top 10 Categories having highest Number of Reviews
top_10_cat = df.groupby('Category')['Rating Count'].max().sort_values(ascending=False).reset_index()
top_10_cat
# Out:
#                    Category  Rating Count
# 0             Communication   138557570.0
# 1                    Social   120206190.0
# 2   Video Players & Editors   112440547.0
# 3                    Action    89177097.0
# 4                  Strategy    56025424.0
# 5               Photography    35369236.0
# 6                     Tools    35128398.0
# 7                    Casual    31476637.0
# 8             Music & Audio    22752840.0
# 9                 Adventure    22148032.0
# 10                   Sports    21754025.0
# 11                 Shopping    18956756.0
# 12           Travel & Local    13576045.0
# 13            Entertainment    12016421.0
# 14             Productivity    11961069.0
# 15                Education    11103561.0
# 16                   Racing    10205496.0
# 17                  Finance     8851930.0
# 18          Personalization     8798409.0
# 19        Maps & Navigation     8649676.0
# 20               Simulation     8424191.0
# ...

# %%
sns.catplot(x='Category',y='Rating Count', data=top_10_cat.head(10),kind='bar')
plt.xticks(rotation=90)
plt.show()

# %%
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# App Name                  0
# App Id                    0
# Category                  0
# Rating                22572
# Rating Count          22572
# Installs                  0
# Minimum Installs          0
# Maximum Installs          0
# Free                      0
# Price                     0
# Currency                  0
# Size                      0
# Minimum Android        6530
# Developer Id              0
# Developer Website    760716
# Developer Email           0
# Released              70748
# Last Updated              0
# Content Rating            0
# Privacy Policy       420845
# Ad Supported              0
# In App Purchases          0
# Editors Choice            0
# Scraped Time              0
# dtype: int64

# %%
df.dropna(subset=['Privacy Policy','Developer Website'],inplace=True)

# %%
len(df)
# Out:
# 1335554

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Released             44711
# Rating               10080
# Rating Count         10080
# Minimum Android       3638
# Developer Id             0
# Editors Choice           0
# In App Purchases         0
# Ad Supported             0
# Privacy Policy           0
# Content Rating           0
# Last Updated             0
# Developer Email          0
# Developer Website        0
# App Name                 0
# App Id                   0
# Size                     0
# Currency                 0
# Price                    0
# Free                     0
# Maximum Installs         0
# Minimum Installs         0
# Installs                 0
# Category                 0
# Scraped Time             0
# dtype: int64

# %%
# What are the top 10 categories in terms of downloads?

df.Category.unique()
# Out:
# array(['Adventure', 'Tools', 'Social', 'Communication', 'Personalization',
#        'Maps & Navigation', 'Travel & Local', 'Food & Drink', 'Puzzle',
#        'Entertainment', 'Photography', 'Health & Fitness', 'Shopping',
#        'Books & Reference', 'Beauty', 'Business', 'Educational',
#        'Lifestyle', 'Music & Audio', 'News & Magazines',
#        'Auto & Vehicles', 'Productivity', 'Education', 'Art & Design',
#        'House & Home', 'Racing', 'Sports', 'Events', 'Finance', 'Weather',
#        'Board', 'Medical', 'Word', 'Action', 'Trivia', 'Simulation',
#        'Video Players & Editors', 'Music', 'Arcade', 'Libraries & Demo',
#        'Casual', 'Dating', 'Strategy', 'Card', 'Role Playing', 'Casino',
#        'Parenting', 'Comics'], dtype=object)

# %%
len(df.Category.unique())
# Out:
# 48

# %%
valu_by_cat= df.Category.value_counts()
valu_by_cat
# Out:
# Education                  130533
# Business                   105933
# Music & Audio               87986
# Lifestyle                   77358
# Tools                       70803
# Entertainment               65531
# Books & Reference           57174
# Health & Fitness            53841
# Shopping                    51592
# Productivity                50167
# Travel & Local              48416
# Food & Drink                47415
# Finance                     46829
# Personalization             37998
# Communication               32254
# Sports                      30355
# News & Magazines            30059
# Social                      28311
# Puzzle                      25618
# Casual                      22593
# Medical                     21776
# Arcade                      20422
# Photography                 17114
# Maps & Navigation           17020
# Educational                 13461
# Simulation                  13005
# Action                      12856
# ...

# %%
valu_by_cat[:10]
# Out:
# Education            130533
# Business             105933
# Music & Audio         87986
# Lifestyle             77358
# Tools                 70803
# Entertainment         65531
# Books & Reference     57174
# Health & Fitness      53841
# Shopping              51592
# Productivity          50167
# Name: Category, dtype: int64

# %%
valu_by_cat[:10].plot(kind='barh')
# Out:
# <AxesSubplot: >

# %%
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice',
#        'Scraped Time'],
#       dtype='object')

# %%
max_install_by_cat=df.groupby(['Category'])[['Maximum Installs']].sum().sort_values(by='Maximum Installs',ascending=False)
max_install_by_cat
# Out:
#                          Maximum Installs
# Category
# Tools                         95172174850
# Communication                 58869828641
# Productivity                  39645952127
# Social                        30459508093
# Video Players & Editors       29470751840
# Casual                        28703086248
# Entertainment                 28450755949
# Action                        28290530735
# Photography                   26300983544
# Arcade                        24038600256
# Music & Audio                 20917850531
# Travel & Local                18147538820
# Puzzle                        17843865612
# Simulation                    17511540548
# Racing                        16191069057
# Sports                        13469898706
# Shopping                      13041644069
# Personalization               11968624020
# Finance                       11002137380
# Education                      9104225318
# Lifestyle                      8897681162
# ...

# %%
max_install_by_cat.head(10)
# Out:
#                          Maximum Installs
# Category
# Tools                         95172174850
# Communication                 58869828641
# Productivity                  39645952127
# Social                        30459508093
# Video Players & Editors       29470751840
# Casual                        28703086248
# Entertainment                 28450755949
# Action                        28290530735
# Photography                   26300983544
# Arcade                        24038600256

# %%
max_install_by_cat.head(10).plot(kind='barh')
# Out:
# <AxesSubplot: ylabel='Category'>

# %%
# What are the top downloaded apps in each of these categories?
top_apps = df.groupby(['App Name'])[['Maximum Installs']].sum().sort_values(by='Maximum Installs', ascending=False)
top_apps.head(10)
# Out:
#                                   Maximum Installs
# App Name
# Google Play services                   12057627016
# YouTube                                 9766230924
# Google                                  9154248491
# Google Maps - Navigate & Explore        9141671889
# Google Text-to-Speech                   9034404884
# Google Chrome: Fast & Secure            8925640788
# Gmail                                   8756574289
# Android Accessibility Suite             7408134567
# Google Drive                            7028265259
# Facebook                                6782619635

# %%
top_apps.head(10).plot(kind='barh')
# Out:
# <AxesSubplot: ylabel='App Name'>

# %%
df = df[df['App Name'] != 'Google Play services']

# %%
top_apps = df.groupby(['App Name'])[['Maximum Installs']].sum().sort_values(by='Maximum Installs', ascending=False)
top_apps.head(10)
# Out:
#                                   Maximum Installs
# App Name
# YouTube                                 9766230924
# Google                                  9154248491
# Google Maps - Navigate & Explore        9141671889
# Google Text-to-Speech                   9034404884
# Google Chrome: Fast & Secure            8925640788
# Gmail                                   8756574289
# Android Accessibility Suite             7408134567
# Google Drive                            7028265259
# Facebook                                6782619635
# WhatsApp Messenger                      6265637751

# %%
top_apps.head(10).plot(kind='barh')
# Out:
# <AxesSubplot: ylabel='App Name'>
